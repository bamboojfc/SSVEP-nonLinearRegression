# %%
import scipy.io

# %%
mat = scipy.io.loadmat('SSVEPDataset.mat')

# %%
print mat
# Out:
# {'__version__': '1.0', 'subject': array([[(array([[15458.42356913],
#        [15440.90664486],
#        [15401.42517477],
#        ...,
#        [18548.04115587],
#        [18562.57808433],
#        [18554.51760225]]), array([[11346.18462549],
#        [11397.85889249],
#        [11423.55593815],
#        ...,
#        [14039.10478417],
#        [14035.26417204],
#        [14046.269512  ]]), array([[9149.03830295],
#        [9143.00495846],
#        [9104.08777463],
#        ...,
#        [7411.94926505],
#        [7450.29729045],
#        [7467.80858391]]), array([[ 7999.89461987],
#        [ 8008.30418783],
#        [ 8064.4570693 ],
#        ...,
#        [10187.93754318],
#        [10148.59233476],
#        [10118.5927099 ]]), array([[19959.00326923],
#        [20011.17922863],
#        [20033.32839887],
#        ...,
#        [22467.85864296],
#        [22470.44748064],
#        [22466.37133838]])),
#         (array([[26522.82656604],
#        [26511.77827349],
# ...
